# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=3, random_state=101)

# %%
data[0][:10]
# Out:
# array([[ -6.42884095,  10.14111739],
#        [  5.86867888,   5.20110356],
#        [ -0.37610937,   3.26427943],
#        [  2.16679181,   9.56300522],
#        [  5.0950857 ,   7.20752718],
#        [-10.87888819,  -6.1131804 ],
#        [  2.03405554,   9.76664755],
#        [ -1.71798771,   1.4140114 ],
#        [  1.16911341,   8.24556988],
#        [ -1.35185444,   3.13245345]])

# %%
data[1][:10]
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0])

# %%
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')

# %%
from sklearn.cluster import KMeans
km= KMeans(n_clusters=4)

# %%
km.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
km.labels_
# Out:
# array([3, 1, 2, 1, 1, 0, 1, 2, 1, 3, 3, 2, 1, 1, 3, 2, 1, 2, 0, 3, 0, 2,
#        1, 0, 3, 0, 0, 2, 1, 1, 3, 0, 1, 2, 2, 3, 0, 0, 0, 2, 0, 3, 1, 3,
#        2, 1, 3, 1, 0, 3, 2, 3, 1, 2, 0, 2, 1, 2, 3, 1, 0, 3, 0, 1, 1, 2,
#        0, 1, 1, 0, 1, 1, 0, 2, 0, 1, 1, 2, 3, 3, 3, 0, 1, 0, 2, 2, 2, 3,
#        2, 0, 0, 0, 0, 2, 1, 0, 1, 3, 0, 1, 3, 0, 1, 2, 3, 3, 0, 1, 0, 0,
#        1, 3, 3, 1, 0, 1, 3, 3, 1, 1, 1, 3, 2, 3, 2, 1, 3, 2, 0, 3, 3, 3,
#        2, 0, 0, 3, 2, 2, 1, 2, 0, 2, 0, 1, 1, 1, 3, 0, 3, 3, 3, 3, 2, 1,
#        2, 3, 2, 1, 1, 2, 1, 2, 3, 3, 0, 3, 2, 1, 3, 2, 1, 2, 3, 1, 1, 3,
#        1, 1, 0, 1, 3, 0, 0, 1, 0, 0, 0, 0, 0, 2, 0, 1, 1, 3, 0, 1, 1, 1,
#        0, 2])

# %%
km.cluster_centers_
# Out:
# array([[-9.49535363, -6.55498117],
#        [ 3.46488654,  7.58740805],
#        [ 0.12611584,  0.87610384],
#        [-4.73655475,  7.54577498]])

# %%
f, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(10,6))
ax2.set_title('KMeans')
ax2.scatter(data[0][:,0], data[0][:,1], c=km.labels_)
ax1.set_title('Original')
ax1.scatter(data[0][:,0], data[0][:,1], c=data[1])
