# %%
import matplotlib.pyplot as plt

# %%
#plt.figure() 주피터 노트북에서 피겨는 미리 해줌

x = [1,2,3,4,5]
y = [6,7,8,9,10]


plt.plot(x,y)

# %%
x = [1,2,3,4,5]
y = [i**2 for i in x]

x1 = [1,2,3,4,5]
y1 = [6,7,8,9,10]

plt.plot(x,y)
plt.plot(x1,y1)

# %%
import numpy as np
x1 = range(50)
y1 = [np.cos(val) for val in x1]

x2 = range(50)
y2 = [np.sin(val) for val in x2]

plt.plot(x1, y1)
plt.plot(x2, y2)

# %%
plt.subplot(1,2,1)#도화지를 1행 2열로 나누고 첫번째 도화지
plt.plot(x1, y1, color='red', linestyle='dotted')

plt.subplot(1,2,2)#도화지를 1행 2열로 나누고 두번째 도화지
plt.plot(x2, y2, color='blue', linestyle='dashed')

# %%
plt.subplot(1,3,1)#도화지를 1행 3열로 나누고 첫번째 도화지
plt.plot(x1, y1, color='red', linestyle='dotted')

plt.subplot(1,3,3)#도화지를 1행 3열로 나누고 세번째 도화지
plt.plot(x2, y2, color='blue')

# %%
plt.figure(figsize=(10,8))

x1 = range(100)
y1 = [val for val in x1]

y2 = [val + 50 for val in x1]

plt.plot(x1,y1,c ='#a52a2a', ls='-.', label='Line 1')
plt.plot(x1,y2, c='green', ls=':', label='Line 2')

plt.text(50,60, 'Line 1')#표 중간에 텍스트 삽입
plt.annotate('Line 2', xytext=(30,110), xy=(50,100), arrowprops=dict(facecolor = 'yellow', shrink=0.1))# 화살표 넣기
plt.legend(fancybox=True, shadow=True, loc='upper right')# 범례표시/위치/모양 변경

plt.xlabel('X axis')#x축 이름
plt.ylabel('Y axis')#y축 이름
plt.title('Line Chart')#표 이름

plt.savefig('Matplotlib Line Chart.png')

# %% [markdown]
# ## Scatter chart

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]


plt.scatter(x,y)

# %%
x = np.random.rand(100)
y = x + np.random.randn(100)/10

plt.scatter(x,y)

# %%
data1 = np.random.rand(512,2)
data1
# Out:
# array([[0.94024809, 0.36909082],
#        [0.3030713 , 0.07628727],
#        [0.73717064, 0.97955143],
#        ...,
#        [0.92755034, 0.42071368],
#        [0.34531588, 0.03856024],
#        [0.02147494, 0.38547743]])

# %%
x = data1[:,0] #[xxx, yyy],[xxx1, yyy1]...[xxxX, yyyY]중에서 전체중 xxx부분만 가져오기
y = data1[:,1] #[xxx, yyy],[xxx1, yyy1]...[xxxX, yyyY]중에서 전체중 yyy부분만 가져오기
plt.scatter(x,y)

# %%
data2 = np.random.rand(512,2)
data2
x1 = data2[:,0] #[xxx, yyy],[xxx1, yyy1]...[xxxX, yyyY]
y1 = data2[:,1]
plt.scatter(x1,y1)

# %%
plt.scatter(data1[:,0], data1[:,1], c='g', marker='x')
plt.scatter(data2[:,0], data2[:,1], c='r', marker='^')

# %%
n = 50
x = np.random.rand(n)
y = np.random.rand(n)

colors = np.random.rand(n)
area = (np.random.rand(n)*30)**2.5

plt.scatter(x,y, c=colors, s=area, alpha = 0.5)

# %% [markdown]
# ## Bar chart

# %%
data = np.array([[5,25,52,20],[4,23,51,17],[6,22,52,9]])
x=np.arange(0,8,2)

# %%
data
# Out:
# array([[ 5, 25, 52, 20],
#        [ 4, 23, 51, 17],
#        [ 6, 22, 52,  9]])

# %%
x
# Out:
# array([0, 2, 4, 6])

# %%
y = data[0]

# %%
plt.bar(x,y, color='g', width=0.5)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Histogram

# %%
x = np.random.randn(10000)
plt.hist(x, bins =100)
plt.show()

# %% [markdown]
# ## Box Plot

# %%
data = np.random.randn(100,5)
data
# Out:
# array([[-8.10108753e-01,  7.52448248e-01, -9.81020438e-02,
#         -1.39182322e+00, -1.03278928e+00],
#        [-3.28734689e-01,  5.67197897e-01,  3.95442445e-01,
#         -1.07894831e-01, -5.36088204e-01],
#        [-8.84270272e-01, -9.69383327e-01, -1.13106260e+00,
#          7.78194268e-03, -7.90577156e-02],
#        [ 1.94309982e+00,  2.40950543e-02, -8.12288151e-01,
#          5.95122148e-01,  1.27065469e+00],
#        [ 4.11565663e-01, -4.21501921e-01,  6.84763990e-01,
#          5.09185773e-01,  1.11919778e+00],
#        [ 4.90700445e-01,  7.82686280e-01, -5.87002725e-01,
#          1.27674734e+00, -6.70017855e-01],
#        [-1.21133254e-02,  9.99167235e-01, -1.06887871e-01,
#          5.12903259e-01, -2.15954509e-01],
#        [ 2.19977351e-01,  6.04311778e-01, -9.59905957e-01,
#          4.34713882e-01,  4.17709472e-01],
#        [ 4.21570802e-01,  6.69843733e-03,  5.23503003e-01,
#         -1.82997432e+00, -7.45898221e-01],
#        [ 5.54471472e-01, -5.35625660e-01, -1.75664445e+00,
#         -3.38604483e-01,  7.10412149e-01],
#        [-1.88940671e+00, -6.17458727e-02, -6.29325823e-01,
#          1.24965605e+00,  1.87063735e+00],
#        [-2.30625638e+00, -1.41520894e+00,  3.83010647e-01,
#         -1.47820130e+00,  1.13479639e+00],
#        [-3.70702455e-01,  7.03777793e-01, -2.41832392e-01,
#         -4.02076208e-01, -1.22539246e+00],
#        [ 1.74389896e-01,  1.09883403e+00,  5.48794548e-02,
#         -2.83391487e-01, -3.48372644e-01],
#        [ 1.41834503e-01,  1.33846403e+00, -2.59978928e-01,
#         -1.58557370e+00,  1.50821491e+00],
#        [-4.74675059e-01,  2.55894018e-01, -1.49632077e+00,
#          9.42233937e-02, -2.79823705e-01],
#        [-7.31286648e-01,  1.09925292e+00, -1.25578642e-01,
#         -1.29669528e+00, -1.54764576e+00],
#        [-2.18912918e+00,  5.01176018e-01,  1.24249630e+00,
#          6.28687093e-01,  5.07555591e-02],
#        [-1.47166479e-01,  1.83567313e-01, -6.01217167e-01,
#          5.81382660e-01, -5.40890469e-01],
#        [-9.47615210e-01, -8.35115270e-02, -1.61175454e+00,
#          8.28376218e-03,  3.36494957e+00],
#        [-6.27667039e-01, -8.68531480e-02, -2.75495215e+00,
#         -4.48244351e-01,  1.35872323e+00],
